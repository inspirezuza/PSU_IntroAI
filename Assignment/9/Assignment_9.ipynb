# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('stdScores.xlsx')
df = df.iloc[:,0:12]

# %%
count = 0
Estudent = df
for i in df['Midterm Grade']:
  if i != 'E' :
    Estudent = Estudent.drop([count])
  count += 1
Estudent
# Out:
#      #  รหัสนักศึกษา  ...  Total (50%)  Midterm Grade
# 0    1    5410110014  ...    20.583333              E
# 6    7    5410110075  ...     9.050000              E
# 8    9    5410110079  ...    22.266667              E
# 11  12    5410110161  ...    17.983333              E
# 13  14    5410110174  ...    12.333333              E
# 16  17    5410110210  ...    23.450000              E
# 17  18    5410110221  ...    17.600000              E
# 21  22    5410110238  ...     4.666667              E
# 24  25    5410110291  ...    23.433333              E
# 27  28    5410110305  ...    23.716667              E
# 28  29    5410110323  ...     2.333333              E
# 33  34    5410110386  ...    18.216667              E
# 35  36    5410110403  ...    24.100000              E
# 40  41    5410110415  ...    15.500000              E
# 42  43    5410110436  ...    19.333333              E
# 54  55    5410110567  ...    22.400000              E
# ...

# %%
is_NaN = df.isnull()
row_has_NaN = is_NaN.any(axis=1)
df[row_has_NaN]
# Out:
#      #  รหัสนักศึกษา  ...  Total (50%)  Midterm Grade
# 7    8    5410110078  ...    28.233333             D+
# 11  12    5410110161  ...    17.983333              E
# 21  22    5410110238  ...     4.666667              E
# 28  29    5410110323  ...     2.333333              E
# 34  35    5410110395  ...    35.566667             B+
# 36  37    5410110405  ...    30.666667              C
#
# [6 rows x 12 columns]

# %%
df = df.dropna(how="any")
df = df.iloc[:,2:]
df.describe()
# Out:
#        Attendances I (10)  Attendances II (5)  ...  Midterm (30%)  Total (50%)
# count           60.000000           60.000000  ...      60.000000    60.000000
# mean             9.133333            4.466667  ...      17.642500    30.023333
# std              1.268479            0.964921  ...       5.462149     8.274904
# min              5.000000            1.000000  ...       5.550000     9.050000
# 25%              8.000000            4.000000  ...      13.762500    24.004167
# 50%             10.000000            5.000000  ...      18.375000    30.600000
# 75%             10.000000            5.000000  ...      21.075000    34.837500
# max             10.000000            5.000000  ...      28.950000    47.000000
#
# [8 rows x 7 columns]

# %%
a = df['Midterm Grade'].tolist()
plot = pd.Series(a).value_counts().sort_index()
plot.plot(kind='bar')

# %%
plot.plot(kind='line')
